# %% [markdown]
# # 03 TTS Train Colab
# Tacotron2 training skeleton.

# %%
from voice_ai.tts.tacotron2 import Tacotron2, Tacotron2Config
from voice_ai.utils.config import load_yaml
import yaml
config_dict = load_yaml("configs/tts_tacotron2_tiny.yaml")
print(config_dict)

# %%
# TODO: Load dataset (e.g., LJSpeech)
# TODO: Set up training loop
# TODO: Save checkpoints to Drive
