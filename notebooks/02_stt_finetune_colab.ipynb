# %% [markdown]
# # 02 STT Fine-tune Colab
# Wav2Vec2 CTC fine-tuning skeleton.

# %%
from voice_ai.stt.wav2vec2_ctc import Wav2Vec2CTCModel
from voice_ai.utils.config import load_yaml
config = load_yaml("configs/stt_wav2vec2_tiny.yaml")
print(config)

# %%
# TODO: Load dataset (e.g., LibriSpeech)
# TODO: Set up training loop
# TODO: Save checkpoints to Drive
