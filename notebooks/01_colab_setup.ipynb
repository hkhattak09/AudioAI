# %% [markdown]
# # 01 Colab Setup
# Clone repo, install requirements, mount Drive, verify GPU.

# %%
# Clone repo
# !git clone https://github.com/YOUR_USERNAME/voice_ai.git
# %cd voice_ai

# %%
# Install dependencies
# !pip install -q -e .

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# Verify GPU
import torch
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Recommended: T4 first, then L4, then A100 for heavier training.
