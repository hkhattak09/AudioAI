# %% [markdown]
# # 00 Local Smoke Test
# Run quick local imports and smoke tests.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
import voice_ai
from voice_ai.audio.features import AudioFeatureConfig, mel_spectrogram
from voice_ai.tts.tacotron2 import Tacotron2, Tacotron2Config
from voice_ai.vocoder.hifigan import Generator, HiFiGANConfig
from voice_ai.pipeline.voice_agent import VoiceAgent
print("Imports OK")

# %%
# !python ../scripts/smoke_test.py
