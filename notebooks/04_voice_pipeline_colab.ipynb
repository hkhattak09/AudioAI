# %% [markdown]
# # 04 Voice Pipeline Colab
# Full voice pipeline with trained checkpoints.

# %%
from voice_ai.pipeline.voice_agent import VoiceAgent
from voice_ai.llm.colab_ai_adapter import ColabAIAdapter
from voice_ai.utils.config import load_yaml
config = load_yaml("configs/pipeline_colab_t4.yaml")
print(config)

# %%
# TODO: Load trained STT, TTS, and vocoder checkpoints
# TODO: Instantiate VoiceAgent with real models
# TODO: Run one full turn: audio -> STT -> LLM -> TTS -> vocoder -> audio
